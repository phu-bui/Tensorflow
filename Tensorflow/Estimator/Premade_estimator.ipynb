# %%
import tensorflow as tf
import pandas as pd 

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

# %%
train_path = tf.keras.utils.get_file("iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file("iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %%
test.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          5.9         3.0          4.2         1.5        1
# 1          6.9         3.1          5.4         2.1        2
# 2          5.1         3.3          1.7         0.5        0
# 3          6.0         3.4          4.5         1.6        1
# 4          5.5         2.5          4.0         1.3        1

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')

# %%
train_y.head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    0
# 4    0
# Name: Species, dtype: int64

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
def input_evaluation_set():
  features = {
      'SepalLength': np.array([6.4, 5.0]),
      'SepalWidth': np.array([2.8, 2.3]),
      'PetalLength': np.array([5.6, 3.3]),
      'PetalWidth': np.array([2.2, 1.0])
  }
  labels = np.array([2, 1])
  return features, labels

# %%
def input_fn(features, labels, training=True, batch_size=256):
    """An input function for training or evaluating"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
my_features_columns = []
for key in train.keys():
  my_features_columns.append(tf.feature_column.numeric_column(key=key))

# %%
# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpaqyqp2xd
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpaqyqp2xd', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# Train the Model.
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpaqyqp2xd/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpaqyqp2xd/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:loss = 0.39531314, step = 10000
# INFO:tensorflow:global_step/sec: 473.474
# INFO:tensorflow:loss = 0.38597202, step = 10100 (0.213 sec)
# INFO:tensorflow:global_step/sec: 673.345
# INFO:tensorflow:loss = 0.38661167, step = 10200 (0.149 sec)
# INFO:tensorflow:global_step/sec: 655.261
# INFO:tensorflow:loss = 0.39787427, step = 10300 (0.152 sec)
# INFO:tensorflow:global_step/sec: 655.805
# INFO:tensorflow:loss = 0.40465707, step = 10400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 629.763
# INFO:tensorflow:loss = 0.40460765, step = 10500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 672.532
# INFO:tensorflow:global_step/sec: 671.881
# INFO:tensorflow:loss = 0.35352528, step = 13500 (0.146 sec)
# INFO:tensorflow:global_step/sec: 646.211
# INFO:tensorflow:loss = 0.35763904, step = 13600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 664.519
# INFO:tensorflow:loss = 0.34453732, step = 13700 (0.153 sec)
# INFO:tensorflow:global_step/sec: 664.936
# INFO:tensorflow:loss = 0.36719024, step = 13800 (0.149 sec)
# INFO:tensorflow:global_step/sec: 616.042
# INFO:tensorflow:loss = 0.35201597, step = 13900 (0.162 sec)
# INFO:tensorflow:global_step/sec: 670.128
# INFO:tensorflow:loss = 0.34551448, step = 14000 (0.150 sec)
# INFO:tensorflow:global_step/sec: 654.855
# INFO:tensorflow:loss = 0.34258178, step = 14100 (0.155 sec)
# INFO:tensorflow:global_step/sec: 678.982
# INFO:tensorflow:loss = 0.33983687, step = 14200 (0.147 sec)
# INFO:tensorflow:global_step/sec: 632.633
# INFO:tensorflow:loss = 0.34562218, step = 14300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 674.757
# INFO:tensorflow:loss = 0.33693945, step = 14400 (0.148 sec)
# INFO:tensorflow:global_step/sec: 662.834
# INFO:tensorflow:loss = 0.3417375, step = 14500 (0.153 sec)
# INFO:tensorflow:global_step/sec: 676.423
# INFO:tensorflow:loss = 0.34334156, step = 14600 (0.145 sec)
# INFO:tensorflow:global_step/sec: 633.831
# INFO:tensorflow:loss = 0.34407693, step = 14700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 675.038
# INFO:tensorflow:loss = 0.33204746, step = 14800 (0.148 sec)
# INFO:tensorflow:global_step/sec: 642.662
# INFO:tensorflow:loss = 0.3285612, step = 14900 (0.156 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 15000...
# INFO:tensorflow:Saving checkpoints for 15000 into /tmp/tmpaqyqp2xd/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 15000...
# INFO:tensorflow:Loss for final step: 0.33338562.

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-05T10:49:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpaqyqp2xd/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.21805s
# INFO:tensorflow:Finished evaluation at 2020-04-05-10:49:24
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.93333334, average_loss = 0.40796977, global_step = 15000, loss = 0.40796977
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: /tmp/tmpaqyqp2xd/model.ckpt-15000
#
# Test set accuracy: 0.933

# %%
# Generate predictions from the model
expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}
def input_fn(features, batch_size=256):
    """An input function for prediction."""
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

predictions = classifier.predict(
    input_fn=lambda: input_fn(predict_x))

# %%
for pred_dict, expec in zip(predictions, expected):
  class_id = pred_dict['class_ids'][0]
  probability = pred_dict['probabilities'][class_id]

  print('Predictions is "{}" ({:.1f}%), expected "{}"'.format(SPECIES[class_id], 100*probability, expec))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpaqyqp2xd/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Predictions is "Setosa" (94.6%), expected "Setosa"
# Predictions is "Versicolor" (50.5%), expected "Versicolor"
# Predictions is "Virginica" (68.3%), expected "Virginica"
